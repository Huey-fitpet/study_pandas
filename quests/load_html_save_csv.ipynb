# %%
import requests
uri = f"https://comp.fnguide.com/SVO2/asp/SVD_Finance.asp?pGB=1&gicode=A005940&cID=&MenuYn=Y&ReportGB=B&NewMenuID=103&stkGb=701"

response = requests.get(uri)

# %%
import pandas as pd
df_html = pd.read_html(io=response.text, encoding='utf-8')
df_html
# Out:
# /tmp/ipykernel_62227/2894291322.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_html = pd.read_html(io=response.text, encoding='utf-8')
# [               IFRS(별도)  2021/12  2022/12  2023/12  2024/09     전년동기 전년동기(%)
#  0                 순이자손익   7330.0   5958.0   6792.0   5049.0   4937.0     2.3
#  1                순수수료손익  10884.0   7573.0   7892.0   7068.0   6001.0    17.8
#  2              금융상품관련손익   1180.0  -1341.0   1220.0   1532.0    124.0  1134.6
#  3        위험회피회계파생상품관련손익      NaN      NaN      NaN      NaN      NaN     NaN
#  4          외환거래(환율변동)손익   1779.0    706.0    618.0    781.0   1307.0   -40.2
#  5              금융자산관련손익     -8.0   -113.0   -873.0   -324.0   -345.0    적자지속
#  6                기타영업손익    675.0    468.0     -9.0    544.0    220.0   147.1
#  7                 순영업수익  21840.0  13251.0  15640.0  14650.0  12244.0    19.7
# ...

# %%
len(df_html)
# Out:
# 6

# %%
df_html[0].to_csv("../datasets/Q_finance_state.csv")

# %%
df_html[0]
# Out:
#                IFRS(별도)  2021/12  2022/12  2023/12  2024/09     전년동기 전년동기(%)
# 0                 순이자손익   7330.0   5958.0   6792.0   5049.0   4937.0     2.3
# 1                순수수료손익  10884.0   7573.0   7892.0   7068.0   6001.0    17.8
# 2              금융상품관련손익   1180.0  -1341.0   1220.0   1532.0    124.0  1134.6
# 3        위험회피회계파생상품관련손익      NaN      NaN      NaN      NaN      NaN     NaN
# 4          외환거래(환율변동)손익   1779.0    706.0    618.0    781.0   1307.0   -40.2
# 5              금융자산관련손익     -8.0   -113.0   -873.0   -324.0   -345.0    적자지속
# 6                기타영업손익    675.0    468.0     -9.0    544.0    220.0   147.1
# 7                 순영업수익  21840.0  13251.0  15640.0  14650.0  12244.0    19.7
# 8               판매비와관리비   9780.0   7749.0   8740.0   7601.0   6525.0    16.5
# 9                  영업이익  12059.0   5502.0   6899.0   7049.0   5719.0    23.3
# 10  영업외수익계산에 참여한 계정 펼치기    130.0    121.0    262.0    411.0     73.0   464.9
# ...

# %%
df_html[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   IFRS(별도)  17 non-null     object
#  1   2021/12   15 non-null     float64
#  2   2022/12   15 non-null     float64
#  3   2023/12   15 non-null     float64
#  4   2024/09   15 non-null     float64
#  5   전년동기      15 non-null     float64
#  6   전년동기(%)   15 non-null     object
# dtypes: float64(5), object(2)
# memory usage: 1.1+ KB

# %%
df_html[0].describe()
# Out:
#             2021/12       2022/12       2023/12       2024/09          전년동기
# count     15.000000     15.000000     15.000000     15.000000     15.000000
# mean    6475.666667   3579.000000   4303.733333   4255.800000   3397.133333
# std     6174.322041   3944.517153   4456.728757   4077.918608   3437.713336
# min       -8.000000  -1341.000000   -873.000000   -324.000000   -345.000000
# 25%     1003.500000    587.000000    919.000000    662.500000    641.500000
# 50%     7330.000000   3385.000000   4350.000000   5049.000000   3632.000000
# 75%    10332.000000   5730.000000   6845.500000   6985.000000   5328.000000
# max    21840.000000  13251.000000  15640.000000  14650.000000  12244.000000

# %%
df_html[0].describe(include="object")
# Out:
#        IFRS(별도) 전년동기(%)
# count        17      15
# unique       17      14
# top       순이자손익    40.2
# freq          1       2
